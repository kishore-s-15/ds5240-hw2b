# %% [markdown]
# ## PROBLEM 8: Hierarchical Clustering

# %%
# Importing the required libraries

import math
import heapq
from pathlib import Path

import numpy as np
import pandas as pd
from scipy.spatial.distance import cdist
from scipy.cluster.hierarchy import dendrogram
from sklearn.preprocessing import MinMaxScaler

import seaborn as sns
import matplotlib.pyplot as plt

np.set_printoptions(suppress=True)
custom_palette = sns.color_palette("tab10", n_colors=10)

# %% [markdown]
# ### Data Preprocessing & Visualization

# %%
# Loading the data

DATA_DIR = Path().cwd().parent / "data"
DATA_URL = DATA_DIR / "moons.csv"

# %%
df = pd.read_csv(DATA_URL)
df.head()
# Out:
#    Xmoons_X1  Xmoons_X2
# 0  -0.378142   0.940750
# 1   0.933566   0.153805
# 2   2.048309   0.498172
# 3   0.947891   0.162473
# 4   2.000739   0.183700

# %%
scaler = MinMaxScaler()

df = pd.DataFrame(data=scaler.fit_transform(df), columns=["x", "y"])

X = df[["x", "y"]].values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       1500 non-null   float64
#  1   y       1500 non-null   float64
# dtypes: float64(2)
# memory usage: 23.6 KB

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y")
plt.title("Visualizing the Moons data")
plt.show()

# %% [markdown]
# ### Custom Hierarchial Clustering Implementation

# %%
class HierarchialClustering:

    def __init__(self, linkage = "single"):
        self.linkage = linkage

        if linkage == "ward":
            self.linkage_distances = dict()

    
    def get_distances(self, a: int, b: int) -> float:
        if a < self.n and b < self.n:
            dist = self.distance_matrix[a, b]
        else:
            if (a, b) in self.linkage_distances:
                dist = self.linkage_distances[(a, b)]
            elif (b, a) in self.linkage_distances:
                dist = self.linkage_distances[(b, a)]
            else:
                dist = np.inf

        return dist


    def ward_linkage(self, s: int, t: int, v: int) -> float:        
        T = len(self.IDS[v]) + len(self.IDS[s]) + len(self.IDS[t])

        s_and_t_dist = self.get_distances(s, t)
        v_and_s_dist = self.get_distances(s, v)
        v_and_t_dist = self.get_distances(t, v)
        
        v_and_s = ((len(self.IDS[v]) + len(self.IDS[s])) / T) * math.pow(v_and_s_dist, 2)
        v_and_t = ((len(self.IDS[v]) + len(self.IDS[t])) / T) * math.pow(v_and_t_dist, 2)
        s_and_t = ((len(self.IDS[s]) + len(self.IDS[t])) / T) * math.pow(s_and_t_dist, 2)

        dist = math.sqrt(v_and_s + v_and_t + s_and_t)

        self.linkage_distances[(self.cluster_id, v)] = dist

        return dist


    def single_linkage(self, u: int, v: int) -> float:        
        u_pts = self.X[list(self.IDS[u])]
        v_pts = self.X[list(self.IDS[v])]

        dist = np.min(cdist(u_pts, v_pts))

        return dist


    def complete_linkage(self, u: int, v: int) -> float:        
        u_pts = self.X[list(self.IDS[u])]
        v_pts = self.X[list(self.IDS[v])]

        dist = np.max(cdist(u_pts, v_pts))

        return dist

    
    def fit(self, X: np.array):
        # Initial Setup
        self.n, self.d = X.shape

        self.X = X
        
        self.C = {i: i for i in range(self.n)}
        self.IDS = {i: set([i]) for i in range(self.n)}

        self.cluster_id = self.n

        
        # Finding the Initial N x N distance matrix
        # and pushing it to the priority queue
        self.distance_matrix = cdist(X, X)

        pq = []
        
        for i in range(self.n):
            for j in range(self.n):
                if i != j:
                    heapq.heappush(pq, (self.distance_matrix[i, j], (i, j)))

        
        # Finding the N - 1 linkages and storing it in the Z matrix
        Z = np.empty(shape=(self.n - 1, 4))
        while len(pq) > 0:
            dist, (s, t) = heapq.heappop(pq)

            if self.C[s] != s or self.C[t] != t:
                continue                    
            
            self.IDS[self.cluster_id] = self.IDS[s].union(self.IDS[t])
            self.C[s] = self.cluster_id
            self.C[t] = self.cluster_id

            self.C[self.cluster_id] = self.cluster_id

            idx = self.cluster_id - self.n

            Z[idx, 0] = s
            Z[idx, 1] = t
            Z[idx, 2] = dist
            Z[idx, 3] = len(self.IDS[self.cluster_id])

            for v in range(self.cluster_id):
                if v not in self.IDS[self.cluster_id]:
                    if self.linkage == "ward":
                        heapq.heappush(pq, (self.ward_linkage(s, t, v), (self.cluster_id, v)))
                    elif self.linkage == "single":
                        heapq.heappush(pq, (self.single_linkage(self.cluster_id, v), (self.cluster_id, v)))
                    else:
                        heapq.heappush(pq, (self.complete_linkage(self.cluster_id, v), (self.cluster_id, v)))

            self.cluster_id += 1

        
        # Plotting the dendrogram
        plt.figure(figsize=(8, 6))
        dn = dendrogram(Z)
        plt.title("Hierarchical Clustering Dendrogram")
        plt.show()

        return Z

    
    def predict(self, Z: np.array, n_clusters: int) -> np.array:
        idx = self.n - n_clusters

        clusters = { i for i in range(self.n + idx) }
        merged_clusters = set()

        for i in range(idx):
            merged_clusters.add(Z[i, 0])
            merged_clusters.add(Z[i, 1])
        
        clusters = clusters.difference(merged_clusters)

        labels = np.empty(shape=(self.n), dtype=int)
        for label_idx, cluster_idx in enumerate(clusters):
            idx = list(self.IDS[cluster_idx])
            labels[idx] = label_idx

        return labels

# %% [markdown]
# #### Single Linkage Runs

# %%
hc = HierarchialClustering(linkage="single")

# %%
Z = hc.fit(X)

# %%
Z
# Out:
# array([[ 579.        ,  748.        ,    0.00028326,    2.        ],
#        [ 380.        ,  951.        ,    0.0003655 ,    2.        ],
#        [ 852.        , 1163.        ,    0.00039019,    2.        ],
#        ...,
#        [2992.        , 2785.        ,    0.03293782,  750.        ],
#        [2995.        , 1372.        ,    0.04469302,  750.        ],
#        [2997.        , 2996.        ,    0.16139699, 1500.        ]])

# %%
Z.shape
# Out:
# (1499, 4)

# %%
df["single_two_clusters"] = hc.predict(Z, n_clusters=2)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='single_two_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Single Linkage - 2 clusters")
plt.show()
# Out:
# /tmp/ipykernel_8958/2531035664.py:2: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.scatterplot(data=df, x="x", y="y", hue='single_two_clusters', palette=custom_palette)

# %%
df["single_five_clusters"] = hc.predict(Z, n_clusters=5)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='single_five_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Single Linkage - 5 Clusters")
plt.show()
# Out:
# /tmp/ipykernel_8958/1185531483.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.scatterplot(data=df, x="x", y="y", hue='single_five_clusters', palette=custom_palette)

# %%
df["single_ten_clusters"] = hc.predict(Z, n_clusters=10)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='single_ten_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Single Linkage - 10 Clusters")
plt.show()

# %% [markdown]
# #### Complete Linkage Runs

# %%
hc = HierarchialClustering(linkage="complete")

# %%
Z = hc.fit(X)

# %%
df["complete_two_clusters"] = hc.predict(Z, n_clusters=2)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='complete_two_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Complete Linkage - 2 Clusters")
plt.show()
# Out:
# /tmp/ipykernel_8958/1934592145.py:2: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.scatterplot(data=df, x="x", y="y", hue='complete_two_clusters', palette=custom_palette)

# %%
df["complete_five_clusters"] = hc.predict(Z, n_clusters=5)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='complete_five_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Complete Linkage - 5 Clusters")
plt.show()
# Out:
# /tmp/ipykernel_8958/2673373862.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.scatterplot(data=df, x="x", y="y", hue='complete_five_clusters', palette=custom_palette)

# %%
df["complete_ten_clusters"] = hc.predict(Z, n_clusters=10)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='complete_ten_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Complete Linkage - 10 Clusters")
plt.show()

# %% [markdown]
# #### Ward Linkage Runs

# %%
hc = HierarchialClustering(linkage="ward")

# %%
Z = hc.fit(X)

# %%
df["ward_two_clusters"] = hc.predict(Z, n_clusters=2)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='ward_two_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Ward Linkage - 2 Clusters")
plt.show()
# Out:
# /tmp/ipykernel_8958/2452413107.py:2: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.scatterplot(data=df, x="x", y="y", hue='ward_two_clusters', palette=custom_palette)

# %%
df["ward_five_clusters"] = hc.predict(Z, n_clusters=5)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='ward_five_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Ward Linkage - 5 Clusters")
plt.show()
# Out:
# /tmp/ipykernel_8958/2119284638.py:2: UserWarning: The palette list has more values (10) than needed (5), which may not be intended.
#   sns.scatterplot(data=df, x="x", y="y", hue='ward_five_clusters', palette=custom_palette)

# %%
df["ward_ten_clusters"] = hc.predict(Z, n_clusters=10)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue='ward_ten_clusters', palette=custom_palette)
plt.title("Hierarchial Clustering - Ward Linkage - 10 Clusters")
plt.show()
