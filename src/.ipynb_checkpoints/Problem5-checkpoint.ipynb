# %% [markdown]
# ## Problem 5 - Custom DBSCAN implementation

# %%
# Importing the required libraries

from pathlib import Path

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the data

DATA_URL = Path().cwd().parent / "data" / "dbscan.csv"

df = pd.read_csv(DATA_URL)
df.head()
# Out:
#    cluster  pt          x          y  num_neighbors neighbors
# 0      NaN   0  51.418089  13.593610              2      0,27
# 1      NaN   1  39.132318  -4.419204              3   1,40,75
# 2      NaN   2  47.807515 -25.822561              1         2
# 3      NaN   3  27.699703  53.434193              1         3
# 4      NaN   4  39.860995   5.676871              3   4,56,75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cluster        0 non-null      float64
#  1   pt             80 non-null     int64
#  2   x              80 non-null     float64
#  3   y              80 non-null     float64
#  4   num_neighbors  80 non-null     int64
#  5   neighbors      80 non-null     object
# dtypes: float64(3), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y")
plt.title("Visualizing the data")
plt.show()

# %%
from scipy.spatial.distance import cdist

def create_neighbors(df: pd.DataFrame, eps: float) -> pd.DataFrame:
    X = df[["x", "y"]]
    distance_matrix = cdist(X, X)

    for idx in range(distance_matrix.shape[0]):
        neighbors_array = np.where(distance_matrix[idx, :] <= eps)[0]
        
        df.loc[idx, "neighbors"] = ",".join(
            list(map(str, neighbors_array))
        )

        df.loc[idx, "num_neighbors"] = neighbors_array.shape[0]

        df.loc[idx, "pt"] = idx

    df = df.astype({"num_neighbors": int, "pt": int})

    df["cluster"] = np.nan
    
    return df

df = create_neighbors(df, eps=7.5)

# %%
df
# Out:
#     cluster  pt          x          y  num_neighbors neighbors
# 0       NaN   0  51.418089  13.593610              1         0
# 1       NaN   1  39.132318  -4.419204              1         1
# 2       NaN   2  47.807515 -25.822561              1         2
# 3       NaN   3  27.699703  53.434193              1         3
# 4       NaN   4  39.860995   5.676871              1         4
# ..      ...  ..        ...        ...            ...       ...
# 75      NaN  75  39.659047   0.230178              1        75
# 76      NaN  76  26.366491   8.798826              1        76
# 77      NaN  77 -36.184060  44.292045              1        77
# 78      NaN  78  44.012085  37.729478              1        78
# 79      NaN  79  -1.393234 -55.293943              1        79
#
# [80 rows x 6 columns]

# %%
class CustomDBSCAN:

    def __init__(self, eps: float, min_pts: int):
        self.eps = eps
        self.min_pts = min_pts

    
    def fit_predict(self, df: pd.DataFrame):        
        cluster_id = 0

        has_set_cluster = False
        num_points_without_cluster = df["cluster"].isna().sum()
        
        while num_points_without_cluster > 0:
            random_starting_point = df[df["cluster"].isna()].sample(n=1)

            queue = []
            queue.append(int(random_starting_point["pt"]))

            has_set_cluster = False

            while len(queue) > 0:
                point = queue.pop(0)

                # If cluster id already set to this point, then continue
                if not np.isnan(df[df["pt"] == point]["cluster"].item()):
                    continue

                # Setting the cluster id to this point
                if has_set_cluster or df[df["pt"] == point]["num_neighbors"].item() >= self.min_pts:
                    df.loc[df["pt"] == point, "cluster"] = cluster_id

                    # Adding all the neighbors to the queue
                    for neighbor in df[df["pt"] == point]["neighbors"].item().split(","):
                        queue.append(int(neighbor))

                    has_set_cluster = True

                else:
                    df.loc[df["pt"] == point, "cluster"] = -1

            if has_set_cluster:
                cluster_id += 1

            num_points_without_cluster = df["cluster"].isna().sum()

        df["cluster"] = df["cluster"].astype(int)
        
        return df

# %%
dbscan = CustomDBSCAN(eps=7.5, min_pts=3)

# %%
result_df = dbscan.fit_predict(df.copy())
# Out:
# /tmp/ipykernel_11976/4177684770.py:18: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   queue.append(int(random_starting_point["pt"]))

# %%
result_df.cluster.value_counts()
# Out:
# cluster
#  0    43
# -1    27
#  1     7
#  2     3
# Name: count, dtype: int64

# %%
colors = {-1: "black", 0: "red", 1: "blue", 2: "green"}  # Define colors for each cluster
markers = {-1: "o", 0: "s", 1: "^", 2: "D"}  # Define marker styles for each cluster

plt.figure(figsize=(8, 6))
sns.scatterplot(data=result_df, x="x", y="y", hue="cluster", style="cluster", palette=colors, markers=markers)
plt.title("Visualizing Custom DBSCAN results")
plt.show()

# %% [markdown]
# ### Benchmarking with Scikit-Learn's DBSCAN

# %%
from sklearn.cluster import DBSCAN

db = DBSCAN(eps=7.5, min_samples=3)

# %%
X = df[["x", "y"]].values

# %%
db.fit(X)
# Out:
# DBSCAN(eps=7.5, min_samples=3)

# %%
colors = {-1: "black", 0: "red", 1: "blue", 2: "green"}  # Define colors for each cluster
markers = {-1: "o", 0: "s", 1: "^", 2: "D"}  # Define marker styles for each cluster

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="x", y="y", hue=db.labels_, style=db.labels_, palette=colors, markers=markers)
plt.title("Visualizing Custom DBSCAN results")
plt.show()
